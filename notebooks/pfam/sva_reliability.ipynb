# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
import relplot as rp

# %%
df = pd.read_csv('/groups/doudna/projects/ronb/conformal_backup/protein-conformal/data/sva_results_2024-05-31.csv')

# %%
df.head()
# Out:
#           p         x      y
# 0  0.000028  0.999852  False
# 1  0.000012  0.999819  False
# 2  0.000083  0.999842  False
# 3  0.000006  0.999827  False
# 4  0.000076  0.999826  False

# %%
# f: array of probabilities [f_i]
# y: array of binary labels [y_i]
f = df['p'].values
y = df['y'].values

calib_error = rp.smECE(f, y)   # compute calibration error (scalar)
print('calibration error:', rp.smECE(f, y))
# Out:
# calibration error: 0.00273631536422354

# %%
fig, ax = rp.rel_diagram(f, y) # plot
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 fig, ax = rp.rel_diagram(f, y) # plot
#
# File ~/miniconda3/envs/conformal-s/lib/python3.11/site-packages/relplot/diagrams.py:471, in rel_diagram(f, y, **kwargs)
#     464 def rel_diagram(
#     465     f : npt.ArrayLike,
#     466     y : npt.ArrayLike,
#     467     **kwargs):
#     468     """Compute and plot the reliability diagram for predictions f_i and labels y_i.
#     469     This convenience function simply composes prepare_rel_diagram and plot_rel_diagram.
#     470     """
# --> 471     diagram = prepare_rel_diagram(f, y, **kwargs)
#     472     return plot_rel_diagram(diagram, **kwargs)
#
# File ~/miniconda3/envs/conformal-s/lib/python3.11/site-packages/relplot/diagrams.py:253, in prepare_rel_diagram(f, y, plot_confidence_band, plot_bag_lines, num_bootstrap, kde_bandwidth, report_CE, report_CE_std, custom_regressor, kernel, **unused_kwargs)
#     251 outputs["ce"] = ice
#     252 if report_CE_std:
# --> 253     res = scipy.stats.bootstrap(
#     254         (f, y),
#     255         smECE_fast,
#     256         paired=True,
#     257         n_resamples=100,
#     258         method="basic",
#     259         confidence_level=0.95,
#     260     )
#     261     ci = res.confidence_interval
#     262     wid = max(ice - ci.low, ci.high - ice)
#
# File ~/miniconda3/envs/conformal-s/lib/python3.11/site-packages/scipy/stats/_resampling.py:656, in bootstrap(data, statistic, n_resamples, batch, vectorized, paired, axis, confidence_level, alternative, method, bootstrap_result, random_state)
#     653         resampled_data.append(resample)
#     655     # Compute bootstrap distribution of statistic
# --> 656     theta_hat_b.append(statistic(*resampled_data, axis=-1))
#     657 theta_hat_b = np.concatenate(theta_hat_b, axis=-1)
#     659 # Calculate percentile interval
#
# File ~/miniconda3/envs/conformal-s/lib/python3.11/site-packages/scipy/stats/_resampling.py:226, in _bootstrap_iv.<locals>.statistic(i, axis, data, unpaired_statistic)
#     224 def statistic(i, axis=-1, data=data_iv, unpaired_statistic=statistic):
#     225     data = [sample[..., i] for sample in data]
# --> 226     return unpaired_statistic(*data, axis=axis)
#
# File ~/miniconda3/envs/conformal-s/lib/python3.11/site-packages/scipy/stats/_resampling.py:40, in _vectorize_statistic.<locals>.stat_nd(axis, *data)
#      37     data = np.split(z, split_indices)
#      38     return statistic(*data)
# ---> 40 return np.apply_along_axis(stat_1d, 0, z)[()]
#
# File ~/miniconda3/envs/conformal-s/lib/python3.11/site-packages/numpy/lib/shape_base.py:379, in apply_along_axis(func1d, axis, arr, *args, **kwargs)
#     375 except StopIteration:
#     376     raise ValueError(
#     377         'Cannot apply_along_axis when any iteration dimensions are 0'
#     378     ) from None
# --> 379 res = asanyarray(func1d(inarr_view[ind0], *args, **kwargs))
#     381 # build a buffer for storing evaluations of func1d.
#     382 # remove the requested axis, and add the new ones on the end.
#     383 # laid out so that each write is contiguous.
#     384 # for a tuple index inds, buff[inds] = func1d(inarr_view[inds])
#     385 buff = zeros(inarr_view.shape[:-1] + res.shape, res.dtype)
#
# File ~/miniconda3/envs/conformal-s/lib/python3.11/site-packages/scipy/stats/_resampling.py:38, in _vectorize_statistic.<locals>.stat_nd.<locals>.stat_1d(z)
#      36 def stat_1d(z):
#      37     data = np.split(z, split_indices)
# ---> 38     return statistic(*data)
#
# File ~/miniconda3/envs/conformal-s/lib/python3.11/site-packages/relplot/metrics.py:102, in smECE_fast(f, y, eps, return_width)
#      99     recalculate_if_necessary(alpha)
#     100     return alpha < eps or alpha < smooth_ece_interpolated(r_values, alpha)
# --> 102 sigma = search_param(check_smooth_ece, start=1, refine=10)
#     103 if return_width:
#     104     return smooth_ece_interpolated(r_values, sigma), sigma
#
# File ~/miniconda3/envs/conformal-s/lib/python3.11/site-packages/relplot/metrics.py:65, in search_param(predicate, start, refine)
#      63 for _ in range(refine):
#      64     midpoint = (start + end) / 2
# ---> 65     if predicate(midpoint):
#      66         end = midpoint
#      67     else:
#
# File ~/miniconda3/envs/conformal-s/lib/python3.11/site-packages/relplot/metrics.py:100, in smECE_fast.<locals>.check_smooth_ece(alpha)
#      98 def check_smooth_ece(alpha):
#      99     recalculate_if_necessary(alpha)
# --> 100     return alpha < eps or alpha < smooth_ece_interpolated(r_values, alpha)
#
# File ~/miniconda3/envs/conformal-s/lib/python3.11/site-packages/relplot/metrics.py:46, in smooth_ece_interpolated(r_grid, sigma)
#      44 kernel = _get_default_kernel()
#      45 ker = kernel(sigma)
# ---> 46 rs = ker.convolve(r_grid, len(r_grid))
#      47 return np.sum(np.abs(rs)) / len(r_grid)
#
# File ~/miniconda3/envs/conformal-s/lib/python3.11/site-packages/relplot/kernels.py:131, in ReflectedGaussianKernel.convolve(self, values, eval_points)
#     129 ker = self.kernel_ev(eval_points)
#     130 ext_vals = np.concatenate([np.flip(values)[:-1], values, np.flip(values)[1:]])
# --> 131 return np.convolve(ext_vals, ker, "valid")[eval_points//2 : eval_points//2 + eval_points]
#
# File ~/miniconda3/envs/conformal-s/lib/python3.11/site-packages/numpy/core/numeric.py:834, in convolve(a, v, mode)
#     832 if len(v) == 0:
#     833     raise ValueError('v cannot be empty')
# --> 834 return multiarray.correlate(a, v[::-1], mode)
#
# KeyboardInterrupt:

# %%
# plt.figure(figsize=(2.5, 2.5))
fig, ax = plt.subplots(figsize=(2.5, 2.5))
rp.rel_diagram_binned(f, y, ax=ax, fig=fig);
ax.set_xlabel(r'$\hat{p}$', fontsize=10)
ax.set_ylabel(r'$E[\text{correct}(X, Z)|\hat{p}]$', fontsize=10)
# ax.set_xticks([0, 0.5, 1], fontsize=10)
# ax.set_yticks([0, 0.5, 1], fontsize=10)
ax.tick_params(axis='both', which='major', labelsize=10)
# ax.text(0.05, 0.95, f'ECE_15 : {ece:.3f}', transform=ax.transAxes, fontsize=8, alpha=0.7, color='gray', verticalalignment='top')
# Add this after the previous code
# This will add a white rectangle to cover the original ECE annotation
for child in ax.get_children():
    if isinstance(child, plt.Text) and 'ECE' in child.get_text():
        child.set_fontsize(10)  # Set to a smaller font size
        break
# ax.text(0.02, 0.98, ' ', transform=ax.transAxes, fontsize=12, 
#         verticalalignment='top', bbox=dict(facecolor='white', edgecolor='none', alpha=1))

# Add a smaller, less prominent ECE annotation
# ece_value = 0.002  # Replace with the actual ECE value if different
# ax.text(0.02, 0.98, f'ECE_15: {ece_value:.3f}', transform=ax.transAxes, fontsize=6, 
#         verticalalignment='top', color='gray', alpha=0.7)
# # save the plot as a pdf
plt.savefig('rel_diagram.pdf', format='pdf', bbox_inches='tight')

# %%
fig, ax = plt.subplots(figsize=(2.5, 2.5))
rp.rel_diagram_binned(f, y, ax=ax, fig=fig)
ax.set_xlabel(r'$\hat{p}$', fontsize=10)
ax.set_ylabel(r'$\mathrm{\mathbb{E}}[\text{correct}(X, Z)|\hat{p}]$', fontsize=10)

# Set ticks without fontsize argument
ax.set_xticks([0, 0.5, 1])
ax.set_yticks([0, 0.5, 1])

# Use tick_params to set fontsize for the tick labels
ax.tick_params(axis='both', which='major', labelsize=10)

# Add logic for adjusting the ECE annotation size
for child in ax.get_children():
    if isinstance(child, plt.Text) and 'ECE' in child.get_text():
        child.set_fontsize(10)  # Adjust the font size of the ECE annotation
        break

# Save the plot as a PDF
plt.savefig('rel_diagram.pdf', format='pdf', bbox_inches='tight')

# %%
# plt.figure(figsize=(2.5, 2.5))
fig, ax = plt.subplots(figsize=(2.5, 2.5))
rp.rel_diagram_binned(f, y, ax=ax, fig=fig);
ax.set_xlabel(r'$f$', fontsize=10)
ax.set_ylabel(r'$E[f|y]$', fontsize=10)
ax.set_xticks([0, 0.5, 1], fontsize=10)
ax.set_yticks([0, 0.5, 1], fontsize=10)
# save the plot as a pdf
plt.savefig('/data/ron/protein-conformal/figs/pfam_new/rel_diagram.pdf', format='pdf', bbox_inches='tight')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 6
#       4 ax.set_xlabel(r'$f$', fontsize=10)
#       5 ax.set_ylabel(r'$E[f|y]$', fontsize=10)
# ----> 6 ax.set_xticks([0, 0.5, 1], fontsize=10)
#       7 ax.set_yticks([0, 0.5, 1], fontsize=10)
#       8 # save the plot as a pdf
#
# File ~/miniconda3/envs/conformal-s/lib/python3.11/site-packages/matplotlib/axes/_base.py:74, in _axis_method_wrapper.__set_name__.<locals>.wrapper(self, *args, **kwargs)
#      73 def wrapper(self, *args, **kwargs):
# ---> 74     return get_method(self)(*args, **kwargs)
#
# File ~/miniconda3/envs/conformal-s/lib/python3.11/site-packages/matplotlib/axis.py:2179, in Axis.set_ticks(self, ticks, labels, minor, **kwargs)
#    2177 if labels is None and kwargs:
#    2178     first_key = next(iter(kwargs))
# -> 2179     raise ValueError(
#    2180         f"Incorrect use of keyword argument {first_key!r}. Keyword arguments "
#    2181         "other than 'minor' modify the text labels and can only be used if "
#    2182         "'labels' are passed as well.")
#    2183 result = self._set_tick_locations(ticks, minor=minor)
#    2184 if labels is not None:
#
# ValueError: Incorrect use of keyword argument 'fontsize'. Keyword arguments other than 'minor' modify the text labels and can only be used if 'labels' are passed as well.

# %%
# plt.figure(figsize=(2.5, 2.5))
fig, ax = plt.subplots(figsize=(2.5, 2.5))
rp.rel_diagram_binned(f, y, ax=ax, fig=fig);
ax.set_xlabel(r'$f$', fontsize=10)
ax.set_ylabel(r'$E[f|y]$', fontsize=10)
ax.set_xticks([0, 0.5, 1], fontsize=10)
ax.set_yticks([0, 0.5, 1], fontsize=10)
# save the plot as a pdf
plt.savefig('/data/ron/protein-conformal/figs/pfam_new/rel_diagram.pdf', format='pdf', bbox_inches='tight')
# Out:
# ---------------------------------------------------------------------------
#
# ValueError                                Traceback (most recent call last)
#
# Cell In[24], line 6
#
#       4 ax.set_xlabel(r'$f$', fontsize=10)
#
#       5 ax.set_ylabel(r'$E[f|y]$', fontsize=10)
#
# ----> 6 ax.set_xticks([0, 0.5, 1], fontsize=10)
#
#       7 ax.set_yticks([0, 0.5, 1], fontsize=10)
#
#       8 # save the plot as a pdf
#
#
#
# File /data/ron/miniconda3/envs/rp/lib/python3.11/site-packages/matplotlib/axes/_base.py:74, in _axis_method_wrapper.__set_name__.<locals>.wrapper(self, *args, **kwargs)
#
#      73 def wrapper(self, *args, **kwargs):
#
# ---> 74     return get_method(self)(*args, **kwargs)
#
#
#
# File /data/ron/miniconda3/envs/rp/lib/python3.11/site-packages/matplotlib/axis.py:2168, in Axis.set_ticks(self, ticks, labels, minor, **kwargs)
#
#    2166 if labels is None and kwargs:
#
#    2167     first_key = next(iter(kwargs))
#
# -> 2168     raise ValueError(
#
#    2169         f"Incorrect use of keyword argument {first_key!r}. Keyword arguments "
#
#    2170         "other than 'minor' modify the text labels and can only be used if "
#
#    2171         "'labels' are passed as well.")
#
#    2172 result = self._set_tick_locations(ticks, minor=minor)
#
#    2173 if labels is not None:
#
#
#
# ValueError: Incorrect use of keyword argument 'fontsize'. Keyword arguments other than 'minor' modify the text labels and can only be used if 'labels' are passed as well.

# %%
diagram = rp.prepare_rel_diagram_binned(f, y) # compute calibration data (dictionary)
# print('calibration error:', diagram['ce']) 
# plt.plot(diagram['mesh'],) # plot the calibration curve manually
fig, ax = rp.plot_rel_diagram_binned(mu=diagram['mu'], buckets=diagram['buckets'], alphas=diagram['alphas'], ece=diagram['ece'], t=diagram['t']) # plot the diagram in a new figure

# %%
import seaborn as sns

# %%
# Set the font scale globally using Seaborn
sns.set(font_scale=1.5)  # Adjust the value as needed

# Create the relplot
g = sns.relplot(x=f, y=y)  # Replace 'x' and 'y' with your actual data

# Adjust font sizes using Matplotlib rcParams
plt.rcParams.update({'axes.labelsize': 16,   # Axis labels
                     'xtick.labelsize': 12,  # X-tick labels
                     'ytick.labelsize': 12,  # Y-tick labels
                     'legend.fontsize': 14,  # Legend font size
                     'legend.title_fontsize': 16})  # Legend title font size

# Optionally, you can also adjust the title font size
g.fig.suptitle('Plot Title', fontsize=18)
# Out:
# Text(0.5, 0.98, 'Plot Title')
